# %% [markdown]
# # Bee Detection: Data Balancing with Augmentation
#
# ## Overview
# This project trains models to detect worker bees and drone bees. The dataset initially suffers from severe class imbalance, which we address through targeted augmentation techniques.
#
# **worker - 0**
# **drone - 1**
#
# ## Workflow
#
# ### 1. Setup and Installation
# In the first section, install the necessary packages.
#
# ### 2. Load Dataset from Roboflow
# load the initial dataset from Roboflow. At this stage, the data is highly imbalanced with significantly fewer drone bees than worker bees.
#
# ### 3. Baseline Training
# Before balancing the data, train a baseline model using the imbalanced dataset. This helps us establish a performance benchmark and understand the impact of class imbalance on model accuracy.
#
# ### 4. Data Balancing with Augmentation
# This is the most exciting part! To balance the dataset:
#
# #### 4.1 Extract Drone Crops
# Extract all drone bee bounding boxes from the training images
#
# #### 4.2 Create Augmented Drones
# - Apply augmentation pipeline using Albumentations:
#   - Horizontal flips
#   - Vertical flips
#   - Brightness/contrast adjustments
#   - Slight rotations (±20°)
#
# #### 4.3 Paste Augmented Drones into Training Images
# - Distribute augmented drones across existing training images
# - Add multiple drones per image to reach target 2:1 worker-to-drone ratio
# - Implement overlap detection to prevent drones from covering existing bees
# - Update YOLO labels with new bounding boxes
#
# ### 5. Final Training
# Train models on the balanced dataset and compare performance metrics with the baseline model.

# %% [markdown]
# #### **Notice:**
# Since the tiles are 1280×1080, we must train YOLO with: <font color='red'>**imgsz=1280**</font>

# %% [markdown]
# ## 1. Install neccesory packages

# %%
! pip install -U opencv-contrib-python ultralytics roboflow

# %%
# !pip install roboflow --quiet

# %%
# !pip install albumentations==1.3.1

# %%
import os, json
from roboflow import Roboflow
from collections import Counter
from pathlib import Path
import yaml
from IPython.display import Image
from ultralytics import YOLO
import albumentations as A
from albumentations.augmentations.transforms import *
import cv2
import numpy as np
import random
import shutil
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %% [markdown]
# ## 2. Loading data

# %%
# Shows project slugs
API_KEY = "YOUR_API_KEY" # insert your own path
rf = Roboflow(api_key=API_KEY)
ws = rf.workspace()
print(ws)
# Out:
# loading Roboflow workspace...
# {
#   "name": "NEW",
#   "url": "new-px8pa",
#   "projects": [
#     "new-px8pa/worker-drone-vbegg"
#   ]
# }

# %%
# Loading dataset from Roboflow
project = rf.workspace("new-px8pa").project("worker-drone-vbegg")
version = project.version(2)
dataset = version.download("yolov8", overwrite=True)
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Worker/Drone-2 to yolov8:: 100%|██████████| 109674/109674 [00:07<00:00, 15391.70it/s]
# Extracting Dataset Version Zip to Worker/Drone-2 in yolov8:: 100%|██████████| 2052/2052 [00:00<00:00, 4904.16it/s]

# %%
base = Path("/content/Worker/Drone-2")

print("IMAGE COUNTS BEFORE FILTERING:")
for split in ["train", "valid", "test"]:
    img_dir = base / split / "images"
    num_images = len(list(img_dir.glob("*.jpg"))) + len(list(img_dir.glob("*.png")))
    print(f"  {split}: {num_images} images")
# Out:
# IMAGE COUNTS BEFORE FILTERING:
#   train: 820 images
#   valid: 100 images
#   test: 100 images

# %%
# Get to know the ratio in our dataset
worker_count = 0
drone_count  = 0
worker_idx = 0
drone_idx = 1
for split in ["train"]:
    lbl_dir = base / split / "labels"
    for lbl_file in lbl_dir.glob("*.txt"):
        with open(lbl_file, "r") as f:
            labels = [line.strip().split()[0] for line in f if line.strip()]
        cls_ids = [int(idx) for idx in labels]
        worker_count += cls_ids.count(worker_idx) if worker_idx is not None else 0
        drone_count  += cls_ids.count(drone_idx)  if drone_idx is not None else 0
print(f"🐝 Worker:Drone ratio = {worker_count/drone_count:.2f}:1")
print(f"Drone count = {drone_count}")
print(f"Worker count = {worker_count}")
# Out:
# 🐝 Worker:Drone ratio = 13.50:1
# Drone count = 468
# Worker count = 6318

# %%
shutil.rmtree("/content/Worker")

# %%
plt.figure(figsize=(6,4))
plt.bar(["Worker", "Drone"], [worker_count, drone_count], color=["#FFD700", "#1E90FF"])
plt.title("Worker vs Drone Count (Train Set)")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ## 3. Train baseline model

# %%
base_path = Path("/content/Worker/Drone-2")
data_yaml_path = base_path / "data.yaml"
if not data_yaml_path.exists():
    print(f"ERROR: data.yaml not found at {data_yaml_path}. Check Roboflow download settings.")
else:
    print(f"Using data configuration from: {data_yaml_path}")

    # pre-trained YOLOv10n model weights
    model = YOLO("yolov10n.pt")

    results = model.train(
        data=str(data_yaml_path),
        epochs=50,
        imgsz=1280,
        name="yolov10_worker_drone_unbalanced_run"
    )

    print("Training Complete!")
# Out:
# Using data configuration from: /content/Worker/Drone-2/data.yaml
# Ultralytics 8.3.234 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/Worker/Drone-2/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=1280, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov10n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=yolov10_worker_drone_unbalanced_run2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/detect/yolov10_worker_drone_unbalanced_run2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1      9856  ultralytics.nn.modules.block.SCDown          [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1     36096  ultralytics.nn.modules.block.SCDown          [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.PSA             [256, 256]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  20                  -1  1     18048  ultralytics.nn.modules.block.SCDown          [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    282624  ultralytics.nn.modules.block.C2fCIB          [384, 256, 1, True, True]
#  23        [16, 19, 22]  1    862108  ultralytics.nn.modules.head.v10Detect        [2, [64, 128, 256]]
# YOLOv10n summary: 223 layers, 2,707,820 parameters, 2,707,804 gradients, 8.4 GFLOPs
#
# Transferred 493/595 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1734.8±414.3 MB/s, size: 107.0 KB)
# train: Scanning /content/Worker/Drone-2/train/labels.cache... 820 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 820/820 1.4Mit/s 0.0s
# albumentations: ImageCompression.__init__() got an unexpected keyword argument 'quality_range'
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 866.2±878.0 MB/s, size: 119.8 KB)
# val: Scanning /content/Worker/Drone-2/valid/labels.cache... 100 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 100/100 117.7Kit/s 0.0s
# Plotting labels to /content/runs/detect/yolov10_worker_drone_unbalanced_run2/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 95 weight(decay=0.0), 108 weight(decay=0.0005), 107 bias(decay=0.0)
# Image sizes 1280 train, 1280 val
# Using 2 dataloader workers
# Logging results to /content/runs/detect/yolov10_worker_drone_unbalanced_run2
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50        12G      3.019      7.525      2.695         36       1280: 100% ━━━━━━━━━━━━ 52/52 1.4s/it 1:12
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.1s/it 8.6s
#                    all        100        810     0.0408      0.884      0.329      0.182
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      11.5G       2.98      5.445      2.532         70       1280: 100% ━━━━━━━━━━━━ 52/52 1.1it/s 48.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.4s
#                    all        100        810       0.84      0.316      0.442      0.229
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      11.4G      3.004      4.467      2.567         50       1280: 100% ━━━━━━━━━━━━ 52/52 1.0it/s 49.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.6s
#                    all        100        810      0.689      0.505      0.584      0.311
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      11.4G      2.974      3.696      2.517         68       1280: 100% ━━━━━━━━━━━━ 52/52 1.0it/s 50.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.7it/s 2.3s
#                    all        100        810      0.513      0.514      0.474      0.199
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      11.3G      2.941      3.115      2.519         35       1280: 100% ━━━━━━━━━━━━ 52/52 1.0it/s 50.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.5s
#                    all        100        810      0.798      0.729      0.787       0.42
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      11.5G      2.847      2.636      2.457         47       1280: 100% ━━━━━━━━━━━━ 52/52 1.0it/s 49.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.6s
#                    all        100        810       0.67      0.701       0.71      0.397
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      11.4G      2.886      2.459      2.501         39       1280: 100% ━━━━━━━━━━━━ 52/52 1.0it/s 50.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.5it/s 2.7s
#                    all        100        810      0.778      0.718      0.773      0.423
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      11.4G      2.844      2.248      2.471         43       1280: 100% ━━━━━━━━━━━━ 52/52 1.0it/s 50.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.5s
#                    all        100        810        0.8      0.652      0.767      0.421
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      11.2G      2.825      2.075      2.457         73       1280: 100% ━━━━━━━━━━━━ 52/52 1.0it/s 50.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.5s
#                    all        100        810      0.851      0.765      0.838       0.51
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      11.4G      2.728      1.906      2.409         28       1280: 100% ━━━━━━━━━━━━ 52/52 1.0it/s 49.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.3it/s 3.0s
#                    all        100        810      0.845      0.816      0.875      0.523
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      11.4G      2.758      1.856      2.442         23       1280: 100% ━━━━━━━━━━━━ 52/52 1.0it/s 50.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.5s
#                    all        100        810      0
0.623
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      11.1G      2.018     0.8556      2.127         27       1280: 100% ━━━━━━━━━━━━ 52/52 1.1it/s 46.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.4s
#                    all        100        810      0.969      0.866      0.945       0.62
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      11.1G      1.993     0.8568      2.107         28       1280: 100% ━━━━━━━━━━━━ 52/52 1.1it/s 47.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.0it/s 2.0s
#                    all        100        810       0.95      0.881      0.947      0.621
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      11.1G      1.968     0.8292      2.097         27       1280: 100% ━━━━━━━━━━━━ 52/52 1.1it/s 46.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.7it/s 2.3s
#                    all        100        810      0.939      0.892      0.943      0.623
#
# 50 epochs completed in 0.765 hours.
# Optimizer stripped from /content/runs/detect/yolov10_worker_drone_unbalanced_run2/weights/last.pt, 5.9MB
# Optimizer stripped from /content/runs/detect/yolov10_worker_drone_unbalanced_run2/weights/best.pt, 5.9MB
#
# Validating /content/runs/detect/yolov10_worker_drone_unbalanced_run2/weights/best.pt...
# Ultralytics 8.3.234 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv10n summary (fused): 102 layers, 2,265,558 parameters, 0 gradients, 6.5 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 75% ━━━━━━━━━─── 3/4 2.0s/it 4.3s<2.0s

# %%
best_model_path = Path("/content/runs/detect/yolov10_worker_drone_unbalanced_run2/weights/best.pt")
best_model = YOLO(str(best_model_path))

metrics = best_model.val()
print("\n--- Model Performance Metrics ---")
print(f"mAP50-95: {metrics.box.map:.4f}")
print(f"mAP50: {metrics.box.map50:.4f}")
# Out:
# Ultralytics 8.3.234 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv10n summary (fused): 102 layers, 2,265,558 parameters, 0 gradients, 6.5 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2486.6±676.9 MB/s, size: 111.7 KB)
# val: Scanning /content/Worker/Drone-2/valid/labels.cache... 100 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 100/100 199.3Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.3it/s 5.6s
#                    all        100        810      0.924      0.879      0.939      0.624
#                      0        100        741        0.9       0.86      0.914      0.629
#                      1         54         69      0.948      0.899      0.964      0.619
# Speed: 27.1ms preprocess, 13.6ms inference, 0.0ms loss, 0.4ms postprocess per image
# Results saved to /content/runs/detect/val4
#
# --- Model Performance Metrics ---
# mAP50-95: 0.6236
# mAP50: 0.9391

# %%
ap_per_class = metrics.box.ap

ap50_per_class = metrics.box.ap50

names = metrics.names
class_names = [names[i] for i in sorted(names.keys())]
print("--- Class-Specific Average Precision (AP) ---")

for i, name in enumerate(class_names):

    ap95_score = ap_per_class[i]
    ap50_score = ap50_per_class[i]

    print(f"\n{name} (Class {i}):")
    print(f"  AP@0.5 (AP50):      {ap50_score:.4f}")
    print(f"  AP@0.5:0.95 (AP95): {ap95_score:.4f}")
# Out:
# --- Class-Specific Average Precision (AP) ---
#
# 0 (Class 0):
#   AP@0.5 (AP50):      0.9144
#   AP@0.5:0.95 (AP95): 0.6286
#
# 1 (Class 1):
#   AP@0.5 (AP50):      0.9639
#   AP@0.5:0.95 (AP95): 0.6185

# %%
matrix_path = "/content/runs/detect/val4/confusion_matrix.png"
normalized_path = "/content/runs/detect/val4/confusion_matrix_normalized.png"

print("Confusion matrix:")

img = mpimg.imread(matrix_path)
plt.imshow(img)
plt.axis('off')
plt.show()

print("\nConfusion matrix normalized:")
img_normalized = mpimg.imread(normalized_path)
plt.imshow(img_normalized)
plt.axis('off')
plt.show()
# Out:
# Confusion matrix:
# Confusion matrix normalized:

# %% [markdown]
# ## 4. Augmentation

# %% [markdown]
# **I cropped drone bee from the images:**

# %%
base = Path("/content/Worker/Drone-2")
train_img = base / "train" / "images"
train_lbl = base / "train" / "labels"

drone_crops = []

print("Extracting drone crops...")

for lbl_path in train_lbl.glob("*.txt"):
    img_path = train_img / (lbl_path.stem + ".jpg")
    img = cv2.imread(str(img_path))
    if img is None:
        continue

    h, w = img.shape[:2]

    with open(lbl_path) as f:
        lines = f.read().splitlines()

    for line in lines:
        cid, cx, cy, bw, bh = line.split()
        cid = int(cid)

        if cid != 1:   # only drones
            continue

        cx = float(cx) * w
        cy = float(cy) * h
        bw = float(bw) * w
        bh = float(bh) * h

        x1 = int(cx - bw/2)
        y1 = int(cy - bh/2)
        x2 = int(cx + bw/2)
        y2 = int(cy + bh/2)

        crop = img[y1:y2, x1:x2].copy()
        min_size = 90

        if crop.size > 0 and crop.shape[0] >= min_size and crop.shape[1] >= min_size:
            drone_crops.append(crop)

print("Drone crops collected:", len(drone_crops))
# Out:
# Extracting drone crops...
# Drone crops collected: 333

# %% [markdown]
# **Saved it into drone_crops_original:**

# %%
SAVE_DIR = Path("/content/drone_crops_original")
SAVE_DIR.mkdir(exist_ok=True)

count = 0
for crop in drone_crops:
    fname = f"drone_{count:04d}.jpg"
    cv2.imwrite(str(SAVE_DIR / fname), crop)
    count += 1

print("Saved", count, "drone crops to:", SAVE_DIR)
# Out:
# Saved 333 drone crops to: /content/drone_crops_original

# %%
N = len(drone_crops)
cols = 5
rows = 2
show_count = min(10, N)

plt.figure(figsize=(12, 10))

for i in range(show_count):
    plt.subplot(rows, cols, i+1)
    plt.imshow(cv2.cvtColor(drone_crops[i], cv2.COLOR_BGR2RGB))
    plt.axis("off")
plt.tight_layout()
plt.show()

# %% [markdown]
# **Augmented the cropped drones:**

# %%
CROP_DIR = Path("/content/drone_crops_original")
AUG_DIR = Path("/content/drone_crops_augmented")
AUG_DIR.mkdir(exist_ok=True)

transform = A.Compose([
    A.HorizontalFlip(p=0.3),
    A.VerticalFlip(p=0.3),
    A.Rotate(limit=25, border_mode=cv2.BORDER_REFLECT),
    A.RandomBrightnessContrast(p=0.4),
    A.GaussNoise(var_limit=(5, 15), p=0.25)
])

idx = 0
for img_path in CROP_DIR.glob("*.jpg"):
    img = cv2.imread(str(img_path))
    for i in range(4):  # create 4 augments per crop
        augmented = transform(image=img)["image"]
        cv2.imwrite(str(AUG_DIR / f"aug_{idx:06d}.jpg"), augmented)
        idx += 1

print("Augmented images saved:", idx)
# Out:
# Augmented images saved: 1332

# %%
AUG_DIR = Path("/content/drone_crops_augmented")

files = sorted(AUG_DIR.glob("*.jpg"))[:10]   # only first 10

plt.figure(figsize=(12, 6))

for i, fp in enumerate(files):
    img = cv2.imread(str(fp))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    plt.subplot(2, 5, i+1)
    plt.imshow(img)
    plt.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Increasing minority class till ratio 2:1

# %%
worker_count = 0
drone_count = 0

for split in ["train"]:
    for lbl_file in (base/split/"labels").glob("*.txt"):
        labels = [line.split()[0] for line in open(lbl_file)]
        worker_count += labels.count("0")
        drone_count  += labels.count("1")

print("Workers:", worker_count)
print("Drones:", drone_count)
# Out:
# Workers: 6318
# Drones: 468

# %%
target_drones = worker_count // 2
needed = target_drones - drone_count
print("Need additional drones:", needed)
# Out:
# Need additional drones: 2691

# %%
import cv2
import random
from pathlib import Path

output_img = base / "train" / "images"
output_lbl = base / "train" / "labels"

source_drones = list(CROP_DIR.glob("*.jpg"))
train_images = list(output_img.glob("*.jpg"))

# Calculate drones per image needed
drones_per_image = (needed // len(train_images)) + 1
print(f"Will try to add ~{drones_per_image} drones per image")

added = 0

for target_img_path in train_images:
    if added >= needed:
        break

    target_img = cv2.imread(str(target_img_path))
    h_target, w_target = target_img.shape[:2]

    # Get corresponding label file
    lbl_path = output_lbl / target_img_path.with_suffix(".txt").name

    # Read existing bboxes to avoid overlap
    existing_bboxes = []
    if lbl_path.exists():
        with open(lbl_path) as f:
            for line in f:
                parts = line.strip().split()
                if len(parts) == 5:
                    cls, xc, yc, w, h = parts
                    existing_bboxes.append({
                        'x': float(xc) * w_target,
                        'y': float(yc) * h_target,
                        'w': float(w) * w_target,
                        'h': float(h) * h_target
                    })

    # Track NEW drones separately
    new_drones = []

    # Try to add multiple drones to this image
    drones_added_to_image = 0
    attempts = 0
    max_attempts = drones_per_image * 20

    while drones_added_to_image < drones_per_image and added < needed and attempts < max_attempts:
        attempts += 1

        # Pick and augment a drone
        drone_img = cv2.imread(str(random.choice(source_drones)))
        augmented_drone = transform(image=drone_img)["image"]
        h_drone, w_drone = augmented_drone.shape[:2]

        # Skip if drone too large
        if h_drone >= h_target * 0.8 or w_drone >= w_target * 0.8:
            continue

        # Try random position
        x = random.randint(0, w_target - w_drone)
        y = random.randint(0, h_target - h_drone)

        # Check overlap with ALL bboxes (existing + new drones)
        all_bboxes = existing_bboxes + new_drones
        overlap = False

        for bbox in all_bboxes:
            bbox_x1 = bbox['x'] - bbox['w']/2
            bbox_x2 = bbox['x'] + bbox['w']/2
            bbox_y1 = bbox['y'] - bbox['h']/2
            bbox_y2 = bbox['y'] + bbox['h']/2

            drone_x1 = x
            drone_x2 = x + w_drone
            drone_y1 = y
            drone_y2 = y + h_drone

            if not (drone_x2 < bbox_x1 or drone_x1 > bbox_x2 or
                    drone_y2 < bbox_y1 or drone_y1 > bbox_y2):
                overlap = True
                break

        if not overlap:
            # Paste drone
            target_img[y:y+h_drone, x:x+w_drone] = augmented_drone

            # Add to new drones list (in YOLO format directly)
            new_drones.append({
                'x': x + w_drone/2,
                'y': y + h_drone/2,
                'w': w_drone,
                'h': h_drone
            })

            drones_added_to_image += 1
            added += 1

    # Save modified image
    cv2.imwrite(str(target_img_path), target_img)

    # Append ONLY the new drones to label file
    if drones_added_to_image > 0:
        # Read existing labels
        existing_lines = []
        if lbl_path.exists():
            with open(lbl_path, "r") as f:
                existing_lines = [line.rstrip('\n') for line in f]

        # Write everything back with new drones
        with open(lbl_path, "w") as f:
            # Write existing labels
            for line in existing_lines:
                f.write(line + '\n')

            # Write new drones
            for drone in new_drones:
                x_center = drone['x'] / w_target
                y_center = drone['y'] / h_target
                width = drone['w'] / w_target
                height = drone['h'] / h_target
                f.write(f"1 {x_center:.6f} {y_center:.6f} {width:.6f} {height:.6f}\n")

        print(f"Added {drones_added_to_image} drones to {target_img_path.name}")

print(f"\nTotal added: {added} drones across {len(train_images)} images")
# Out:
# Will try to add ~4 drones per image
# Added 4 drones to GH010991_MP4_frame_14_tile2_jpg.rf.fe3bd5b252149ad99278382d51b3cc1f.jpg
# Added 4 drones to GH010990_MP4_frame_1111_tile0_jpg.rf.59b6c6873515190c7c29964da5834f95.jpg
# Added 4 drones to GH010990_MP4_frame_1221_tile0_jpg.rf.29a65b6ff878c10023352ce0f1a71a2f.jpg
# Added 4 drones to GH010991_MP4_frame_78_tile0_jpg.rf.53890436f11c8b4ca29d78464529e185.jpg
# Added 4 drones to GH010990_MP4_frame_1202_tile0_jpg.rf.e852fa747073ffaadcaf78ad1f1dbf84.jpg
# Added 4 drones to GH010991_MP4_frame_63_tile1_jpg.rf.b0b521c5551555efec2d0618862b539a.jpg
# Added 4 drones to GH010990_MP4_frame_1009_tile0_jpg.rf.2e7147f65fc9ef92332e192ca28a05fb.jpg
# Added 4 drones to GH010990_MP4_frame_965_tile1_jpg.rf.c144946c43802f1e471689564e103600.jpg
# Added 4 drones to GH010990_MP4_frame_1187_tile0_jpg.rf.a0dd1dd6f1e3a0099870a6ab5aac0157.jpg
# Added 4 drones to GH010990_MP4_frame_961_tile1_jpg.rf.0a6ffbe55016e64b2c8d3f7c33020bee.jpg
# Added 4 drones to GH010990_MP4_frame_1163_tile0_jpg.rf.8185af12193771e5df59017a8c486a97.jpg
# Added 4 drones to GH010991_MP4_frame_6_tile1_jpg.rf.7bc0a97863d30e6809ebd109fae55166.jpg
# Added 4 drones to GH010990_MP4_frame_1149_tile1_jpg.rf.3d5dee2df9d80c0f00e7dafe7fb89ac9.jpg
# Added 4 drones to GH010991_MP4_frame_6_tile0_jpg.rf.ca64041cb4f5066ef17be85276b3053a.jpg
# Added 4 drones to GH010991_MP4_frame_88_tile1_jpg.rf.5ef97bcb33be3c82357cb637e77bdc2a.jpg
# Added 4 drones to GH010990_MP4_frame_1194_tile1_jpg.rf.f136cee8b6720e06d2ebaba7a4b7835d.jpg
# Added 4 drones to GH010991_MP4_frame_98_tile2_jpg.rf.9bd1591c00f077aad0411362693d2df0.jpg
# Added 4 drones to GH010990_MP4_frame_840_tile1_jpg.rf.44bc0d5afcd9eea172ded87826e9ae4d.jpg
# Added 4 drones to GH010990_MP4_frame_818_tile2_jpg.rf.14fad95012eca383456fd331ad9e7c9b.jpg
# Added 4 drones to GH010990_MP4_frame_1181_tile0_jpg.rf.57e7d5f3165d5812b34ba2cd0aa17c34.jpg
# Added 4 drones to GH010990_MP4_frame_1209_tile1_jpg.rf.773c3bcc09bf2e37ed8159e1ccd62704.jpg
# Added 4 drones to GH010990_MP4_frame_800_tile0_jpg.rf.38b89c781b363bf0cdef151a4195458c.jpg
# Added 4 drones to GH010990_MP4_frame_803_tile1_jpg.rf.21ef8eb608c68d1bbe2ea74d63f62859.jpg
# Added 4 drones to GH010990_MP4_frame_1183_tile1_jpg.rf.23b55951d7b6e5ccccfbb92d8490c718.jpg
# Added 4 drones to GH010990_MP4_frame_1113_tile2_jpg.rf.5f89c82a40b3e9630e9fc84874c654a9.jpg
# Added 4 drones to GH010990_MP4_frame_1219_tile0_jpg.rf.9ad3bd0d0ea5fc64eddc63f08c5928e5.jpg
# Added 4 drones to GH010991_MP4_frame_26_tile1_jpg.rf.908dddf9cf7f884d39ec7f1de97342b2.jpg
# Added 4 drones to GH010990_MP4_frame_1147_tile1_jpg.rf.ef50acf88ba087f72144adc66d1fa804.jpg
# Added 4 drones to GH010990_MP4_frame_779_tile0_jpg.rf.c8eba18446d70cce4c470d42abd5b84e.jpg
# Added 4 drones to GH010990_MP4_frame_1175_tile2_jpg.rf.de03254a4d66414594baf227aabebdb6.jpg
# Added 4 drones to GH010990_MP4_frame_828_tile1_jpg.rf.89ba90c1a7c287c6d8e396618e1be07b.jpg
# Added 4 drones to GH010990_MP4_frame_1150_tile1_jpg.rf.db4e042d5abb3eb275d1fb488fd9a946.jpg
# Added 4 drones to GH010991_MP4_frame_39_tile2_jpg.rf.e34ab5b7905896bbab711995486dc61c.jpg
# Added 4 drones to GH010991_MP4_frame_15_tile0_jpg.rf.1212da74112cb299235511c77f34ca10.jpg
# Added 4 drones to GH010990_MP4_frame_1160_tile0_jpg.rf.d76ec1f5ef16832358b745ad7079effb.jpg
# Added 4 drones to GH010990_MP4_frame_783_tile1_jpg.rf.7acca53b0460f703779d331aed12b7a8.jpg
# Added 4 drones to GH010990_MP4_frame_1172_tile2_jpg.rf.633974fe45769d0c7f3122b27791cb4e.jpg
# Added 4 drones to GH010991_MP4_frame_51_tile0_jpg.rf.f7e57e929c9e1a7bd1d649304839a10b.jpg
# Added 4 drones to GH010991_MP4_frame_92_tile1_jpg.rf.100acb5f7c74d226173d9c212d41a305.jpg
# Added 4 drones to GH010991_MP4_frame_44_tile2_jpg.rf.19f81c0be16f1d4823bdf2107a518076.jpg
# Added 4 drones to GH010991_MP4_frame_24_tile0_jpg.rf.96cb931d06cb0b5d4ac082c9c609986b.jpg
# Added 4 drones to GH010990_MP4_frame_1132_tile2_jpg.rf.50c760c366563f9365f6370e09151728.jpg
# Added 4 drones to GH010990_MP4_frame_946_tile2_jpg.rf.7802a413681dd6440b2a3655b66be0d0.jpg
# Added 4 drones to GH010991_MP4_frame_5_tile2_jpg.rf.b4d20a34ac99eef281b1eabec6c76c7f.jpg
# Added 4 drones to GH010990_MP4_frame_1134_tile1_jpg.rf.2399a5616d15f8e7cdd4ed9faa24e307.jpg
# Added 4 drones to GH010990_MP4_frame_779_tile2_jpg.rf.c927f856d7eb690c0135517b895f336c.jpg
# Added 4 drones to GH010990_MP4_frame_1006_tile1_jpg.rf.88dac216c31c5682b27ee41bb001f6d8.jpg
# Added 4 drones to GH010990_MP4_frame_963_tile1_jpg.rf.cca84d75cf730c43cdd274e37bace450.jpg
# Added 4 drones to GH010991_MP4_frame_73_tile0_jpg.rf.f04ea07d1e2e09f2a5cb4335bbfeda94.jpg
# Added 4 drones to GH010990_MP4_frame_1005_tile1_jpg.rf.b770d8642418c2717d221cfe20dbed84.jpg
# Added 4 drones to GH010991_MP4_frame_107_tile2_jpg.rf.827c871a55a9cbb49ad5cf1f9d1b211d.jpg
# Added 4 drones to GH010990_MP4_frame_1018_tile0_jpg.rf.15608baba589908574a7428a3a8d4c78.jpg
# Added 4 drones to GH010991_MP4_frame_4_tile2_jpg.rf.77b3cefec7c46a347ac76856739bf710.jpg
# Added 4 drones to GH010990_MP4_frame_820_tile1_jpg.rf.0fb0e22ddc3118209d1dec9c3156a7b7.jpg
# Added 4 drones to GH010990_MP4_frame_1004_tile0_jpg.rf.ae2a2dd454e461b46fef80a1e2b81e5d.jpg
# Added 4 drones to GH010991_MP4_frame_14_tile1_jpg.rf.5bd27ec538ba31b2d3a7efaeed48f9a2.jpg
# Added 4 drones to GH010990_MP4_frame_1230_tile2_jpg.rf.f4805b4a92f1d2ee245910320d51f150.jpg
# Added 4 drones to GH010990_MP4_frame_800_tile2_jpg.rf.23c40697786e9bc5d8ce4f1ceb648d03.jpg
# Added 4 drones to GH010991_MP4_frame_61_tile0_jpg.rf.29ee165ab867fce11a2b305da829c44a.jpg
# Added 4 drones to GH010990_MP4_frame_830_tile0_jpg.rf.7188e08f0a436995b40a4423402351e6.jpg
# Added 4 drones to GH010990_MP4_frame_1129_tile0_jpg.rf.d7d5d02ab481d4774e9c990cd3f925cc.jpg
# Added 4 drones to GH010991_MP4_frame_22_tile2_jpg.rf.21da332fee2acc729fb3db53ed1c6600.jpg
# Added 4 drones to GH010990_MP4_frame_990_tile2_jpg.rf.fb3a52519196b537c31be4ea4bd73d27.jpg
# Added 4 drones to GH010990_MP4_frame_1008_tile2_jpg.rf.69097eb145ad9de2dba76efe3d3a1f49.jpg
# Added 4 drones to GH010991_MP4_frame_56_tile0_jpg.rf.95babe56e751e4994199ae188ed63555.jpg
# Added 4 drones to GH010990_MP4_frame_822_tile2_jpg.rf.dd8d6034b0e5df0727679c715b1aced8.jpg
# Added 4 drones to GH010990_MP4_frame_1135_tile2_jpg.rf.caa3de6bed7cf361f25ea165ba46e867.jpg
# Added 4 drones to GH010990_MP4_frame_1128_tile1_jpg.rf.50555cd1bf33e2b13caaadc93baface9.jpg
# Added 4 drones to GH010991_MP4_frame_65_tile1_jpg.rf.805040bda788ac0986dbb38a79625405.jpg
# Added 4 drones to GH010991_MP4_frame_18_tile1_jpg.rf.a936a3b1ce730822d1b4885c1dfed5f4.jpg
# Added 4 drones to GH010990_MP4_frame_1212_tile2_jpg.rf.bbfcbb512664aebc1a8c30f5e874f5fe.jpg
# Added 4 drones to GH010990_MP4_frame_1117_tile0_jpg.rf.c7f6d137dd8922c8e6f0ab1ab440b250.jpg
# Added 4 drones to GH010991_MP4_frame_33_tile1_jpg.rf.7e3056f58afa64337444b17815e41e54.jpg
# Added 4 drones to GH010991_MP4_frame_8_tile2_jpg.rf.dcf6a6fae95691d0c48ee879550756d2.jpg
# Added 4 drones to GH010991_MP4_frame_101_tile0_jpg.rf.3b79bf144bb0389f2986cb0e2d1daf6c.jpg
# Added 4 drones to GH010990_MP4_frame_818_tile1_jpg.rf.b8368824985137fcab86063907dc3af3.jpg
# Added 4 drones to GH010991_MP4_frame_60_tile0_jpg.rf.84b26a475e2c70b6e1b3ee5fe33320ea.jpg
# Added 4 drones to GH010991_MP4_frame_50_tile0_jpg.rf.a2b1ecff80e93125256adc17f8d33b41.jpg
# Added 4 drones to GH010991_MP4_frame_22_tile0_jpg.rf.fd7382dc16ae41922ab625b2f1403a51.jpg
# Added 4 drones to GH010990_MP4_frame_1134_tile0_jpg.rf.b8ed9e3279360694d5ded5c8702d9dc4.jpg
# Added 4 drones to GH010990_MP4_frame_1216_tile0_jpg.rf.36bbbe88ae97456f7b18d5000b6b391d.jpg
# Added 4 drones to GH010990_MP4_frame_992_tile2_jpg.rf.4f8cffbca254d2158f1738dc70708dd9.jpg
# Added 4 drones to GH010990_MP4_frame_1171_tile0_jpg.rf.033ae783b0e5c2c6b53f1bcc7b4cb140.jpg
# Added 4 drones to GH010990_MP4_frame_1189_tile2_jpg.rf.fa768c816a3f25dc9949c5fadde3fdd0.jpg
# Added 4 drones to GH010990_MP4_frame_1017_tile0_jpg.rf.ec71d08014bfefa394278dfd3635be90.jpg
# Added 4 drones to GH010991_MP4_frame_77_tile1_jpg.rf.28f2408456ae091aad8589a5509f9e89.jpg
# Added 4 drones to GH010990_MP4_frame_1189_tile1_jpg.rf.7fb43018fc4406406dd1ddb877ccc021.jpg
# Added 4 drones to GH010991_MP4_frame_15_tile2_jpg.rf.8705cfbc5f0a3a33fb4bfb7bd70ddb0d.jpg
# Added 4 drones to GH010990_MP4_frame_1180_tile1_jpg.rf.2e5e66325e1d83126602ec0979b41ace.jpg
# Added 4 drones to GH010991_MP4_frame_2_tile1_jpg.rf.a1657526dff50de5439aeff7756ad4c9.jpg
# Added 4 drones to GH010991_MP4_frame_44_tile0_jpg.rf.9af79085261e9ef2e247c800ff60e5bc.jpg
# Added 4 drones to GH010990_MP4_frame_1137_tile1_jpg.rf.c020c6541aed43e3d1508111bac14769.jpg
# Added 4 drones to GH010990_MP4_frame_1185_tile1_jpg.rf.09f1d59fdacc77d4313252a152206a23.jpg
# Added 4 drones to GH010990_MP4_frame_1219_tile2_jpg.rf.7ad66f724a299d84e706a7adc9a3a034.jpg
# Added 4 drones to GH010990_MP4_frame_1223_tile0_jpg.rf.315c34f579f4e1df282b34a2d094cecb.jpg
# Added 4 drones to GH010990_MP4_frame_849_tile1_jpg.rf.7b09322ee44a77779eaee8b1aa986a17.jpg
# Added 4 drones to GH010990_MP4_frame_820_tile2_jpg.rf.227f5d95d8a24116db414748397f23f5.jpg
# Added 4 drones to GH010991_MP4_frame_48_tile0_jpg.rf.64862b33792195496e321cd18868cbaa.jpg
# Added 4 drones to GH010991_MP4_frame_47_tile2_jpg.rf.2b30fce2d6157151dbe39abd3eb778e0.jpg
# Added 4 drones to GH010990_MP4_frame_1188_tile1_jpg.rf.ad6b8a65c3ab5154ef427de39b31f889.jpg
# Added 4 drones to GH010990_MP4_frame_1229_tile2_jpg.rf.b21411c779cb05a046f59ea9bf74ea4c.jpg
# Added 4 drones to GH010991_MP4_frame_111_tile0_jpg.rf.959b807b3f5cd72450468c68bac9b609.jpg
# Added 4 drones to GH010990_MP4_frame_1149_tile2_jpg.rf.4b55d14b1bda79485791cbb6606ce820.jpg
# Added 4 drones to GH010990_MP4_frame_821_tile1_jpg.rf.d75d461b7078d6f1b9b1d40beb175776.jpg
# Added 4 drones to GH010990_MP4_frame_803_tile2_jpg.rf.f0968705c93432b365238867776f01ad.jpg
# Added 4 drones to GH010990_MP4_frame_1214_tile1_jpg.rf.abcd5d9985bc45c094bc9138a4d3e220.jpg
# Added 4 drones to GH010991_MP4_frame_41_tile1_jpg.rf.98726f6f465f892634c102d511097e01.jpg
# Added 4 drones to GH010990_MP4_frame_963_tile2_jpg.rf.18208243bef7c8d002ca165402eee014.jpg
# Added 4 drones to GH010991_MP4_frame_68_tile1_jpg.rf.b5f67e9ae727ce7b034e234818eda409.jpg
# Added 4 drones to GH010990_MP4_frame_776_tile2_jpg.rf.619a2ba92f392301333997fd4153e809.jpg
# Added 4 drones to GH010990_MP4_frame_826_tile2_jpg.rf.88a4da04bac6a434db87811fe41b985a.jpg
# Added 4 drones to GH010991_MP4_frame_85_tile2_jpg.rf.97333be47f90507adde5aaf8be9606a3.jpg
# Added 4 drones to GH010990_MP4_frame_1107_tile2_jpg.rf.3b5f88aee2f84a3152cc99ce17e563c2.jpg
# Added 4 drones to GH010990_MP4_frame_783_tile0_jpg.rf.4e9e225aad54a0722ebed237f75cadef.jpg
# Added 4 drones to GH010990_MP4_frame_946_tile0_jpg.rf.98f0aac013cf8280c0f0a88c41d81a5f.jpg
# Added 4 drones to GH010991_MP4_frame_72_tile0_jpg.rf.67f8774d5edc8df6cf7ff1abbd20ef03.jpg
# Added 4 drones to GH010990_MP4_frame_1209_tile2_jpg.rf.609ae6d03bb7419e6688eb3281dc67ea.jpg
# Added 4 drones to GH010990_MP4_frame_815_tile1_jpg.rf.cef39e85352b8b9441b59d77ef629dc8.jpg
# Added 4 drones to GH010990_MP4_frame_1133_tile0_jpg.rf.dbc9294bd6ec0844541573e9ac532a8f.jpg
# Added 4 drones to GH010990_MP4_frame_955_tile0_jpg.rf.ac5ac85c1764b906f76fc29ee5ccca49.jpg
# Added 4 drones to GH010990_MP4_frame_1136_tile2_jpg.rf.c3ec3f0393382ec2ded456ef47e854b9.jpg
# Added 4 drones to GH010990_MP4_frame_777_tile1_jpg.rf.d44410c1b46cc84661d90c5c5afc7979.jpg
# Added 4 drones to GH010990_MP4_frame_975_tile1_jpg.rf.562a0028f2f74ebfa4eed86a874353b1.jpg
# Added 4 drones to GH010990_MP4_frame_964_tile0_jpg.rf.df8d1a74dbb83e90894b742e293fe3ac.jpg
# Added 4 drones to GH010990_MP4_frame_956_tile0_jpg.rf.c67ac6a76f608de92417d76e6b86ed5b.jpg
# Added 4 drones to GH010991_MP4_frame_79_tile0_jpg.rf.a1fb9ce2b9f223e224cfcefa0e52a4ff.jpg
# Added 4 drones to GH010991_MP4_frame_91_tile2_jpg.rf.859a29001c337510106bdc2a7dedb4fc.jpg
# Added 4 drones to GH010990_MP4_frame_945_tile1_jpg.rf.671e0f3a5d11cb2db5ff51f34fb5d91e.jpg
# Added 4 drones to GH010990_MP4_frame_841_tile0_jpg.rf.5b85dfce7a179b322656f2095d128138.jpg
# Added 4 drones to GH010991_MP4_frame_89_tile1_jpg.rf.1f8c0bc4d1cd73c532b55ef595ab61f5.jpg
# Added 4 drones to GH010990_MP4_frame_846_tile0_jpg.rf.73849617dd8da9ef9df7268e48a296eb.jpg
# Added 4 drones to GH010991_MP4_frame_99_tile2_jpg.rf.564dd4912dd6c562b3b7c704e5e8d62d.jpg
# Added 4 drones to GH010990_MP4_frame_1190_tile1_jpg.rf.c3f4f2187f3e43a5b9b5eafc73473efe.jpg
# Added 4 drones to GH010991_MP4_frame_44_tile1_jpg.rf.cf8f40dc35bad64499f4c9deff34b534.jpg
# Added 4 drones to GH010990_MP4_frame_787_tile1_jpg.rf.375b57b4a37d7fd872a667fe0a236f9c.jpg
# Added 4 drones to GH010990_MP4_frame_967_tile0_jpg.rf.26e2db0a53568279ad8767a77c5bf4d5.jpg
# Added 4 drones to GH010990_MP4_frame_1169_tile2_jpg.rf.29c74fa7c7984e4da117f59e50730ec1.jpg
# Added 4 drones to GH010991_MP4_frame_23_tile1_jpg.rf.ac324ce0ed7148e084664f95735f0e7e.jpg
# Added 4 drones to GH010990_MP4_frame_777_tile0_jpg.rf.b26580c79686c35cea321139eed4e0e4.jpg
# Added 4 drones to GH010990_MP4_frame_991_tile0_jpg.rf.0830b37ddb4a1ca38318486b27f32a9d.jpg
# Added 4 drones to GH010990_MP4_frame_1215_tile1_jpg.rf.e9895d9bad152eeb23eb2019c697a2c1.jpg
# Added 4 drones to GH010990_MP4_frame_1120_tile0_jpg.rf.235d4bb2d5e5df2cedf2b6e730094a31.jpg
# Added 4 drones to GH010990_MP4_frame_1014_tile1_jpg.rf.aa19feff47fd8f875a454738e5b98c57.jpg
# Added 4 drones to GH010990_MP4_frame_959_tile1_jpg.rf.fbf810cfa8f3b7828da5030f1b4e1dc9.jpg
# Added 4 drones to GH010990_MP4_frame_814_tile2_jpg.rf.193c1788bf217414adf9c45717b5c509.jpg
# Added 4 drones to GH010990_MP4_frame_938_tile2_jpg.rf.4b3ff2068cbdcd5c9794761f0f76e957.jpg
# Added 4 drones to GH010991_MP4_frame_79_tile2_jpg.rf.1baccd617e27040931dd231d1d5dac64.jpg
# Added 4 drones to GH010990_MP4_frame_1114_tile1_jpg.rf.1f1a5b86e6319d7dc8957d56f0873cd9.jpg
# Added 4 drones to GH010990_MP4_frame_778_tile0_jpg.rf.dce4a413d20dcec125245cbdf762b6b9.jpg
# Added 4 drones to GH010991_MP4_frame_46_tile1_jpg.rf.eb7d7a35fc17ac3ddc4b77ca858625d4.jpg
# Added 4 drones to GH010990_MP4_frame_1184_tile1_jpg.rf.8c63beddf760450c424e83efe09cd055.jpg
# Added 4 drones to GH010990_MP4_frame_953_tile1_jpg.rf.7d39954e4bc99ba14c39d801c937fe0d.jpg
# Added 4 drones to GH010990_MP4_frame_1210_tile2_jpg.rf.d41808c992cc133c7fd28eec7b18879d.jpg
# Added 4 drones to GH010990_MP4_frame_1152_tile2_jpg.rf.24bc7667b966327487818545e3672fc0.jpg
# Added 4 drones to GH010990_MP4_frame_1170_tile2_jpg.rf.31d63ef7aa89f000b5bc9fe5d4818fbd.jpg
# Added 4 drones to GH010990_MP4_frame_1004_tile2_jpg.rf.761dbbe856ba69fb56574b0a35704c24.jpg
# Added 4 drones to GH010991_MP4_frame_19_tile2_jpg.rf.076a6522b9df72e77553463eb03eff3a.jpg
# Added 4 drones to GH010991_MP4_frame_70_tile0_jpg.rf.db3273bbb855e908606aaf6ad2611582.jpg
# Added 4 drones to GH010990_MP4_frame_1227_tile1_jpg.rf.163b301622d54afd3d61411c94e87a68.jpg
# Added 4 drones to GH010991_MP4_frame_109_tile0_jpg.rf.565a8e8ac99e5bc0967d776459e1a557.jpg
# Added 4 drones to GH010990_MP4_frame_1225_tile0_jpg.rf.c011c35b6191fe4516ce2a91a862ef0e.jpg
# Added 4 drones to GH010991_MP4_frame_88_tile0_jpg.rf.3321949ea06a40b895b7f1390841e342.jpg
# Added 4 drones to GH010990_MP4_frame_1015_tile1_jpg.rf.a6c0a0ce14512868c5c3167a339e5182.jpg
# Added 4 drones to GH010990_MP4_frame_1206_tile2_jpg.rf.cbe0e53838b5d411551ed2405805deb7.jpg
# Added 4 drones to GH010990_MP4_frame_817_tile1_jpg.rf.5e4ea1e8d7499acf560f0ede7d763e76.jpg
# Added 4 drones to GH010991_MP4_frame_87_tile2_jpg.rf.274c8774a9caa4680650d8bde6374b3d.jpg
# Added 4 drones to GH010990_MP4_frame_1159_tile2_jpg.rf.0e126cbf3bd169f0396ea828eb93e5be.jpg
# Added 4 drones to GH010991_MP4_frame_84_tile0_jpg.rf.4743bfd4b589026e159b2c8009c2af76.jpg
# Added 4 drones to GH010990_MP4_frame_995_tile0_jpg.rf.44fe28fb950161583d3e462ed9d19fc7.jpg
# Added 4 drones to GH010991_MP4_frame_11_tile0_jpg.rf.9ad57dcb9487aee3e0b1b449b6b00cf3.jpg
# Added 4 drones to GH010990_MP4_frame_1220_tile2_jpg.rf.dff1282be10605665c0a69df4481ab63.jpg
# Added 4 drones to GH010990_MP4_frame_966_tile1_jpg.rf.fdee17cb27edde8faadd4141ec4dacd0.jpg
# Added 4 drones to GH010990_MP4_frame_947_tile1_jpg.rf.048175ce42c11e9f2fa3a047ead96895.jpg
# Added 4 drones to GH010990_MP4_frame_941_tile0_jpg.rf.e0d2cc11a78d9d2d12c60aa45b205355.jpg
# Added 4 drones to GH010990_MP4_frame_1129_tile2_jpg.rf.c5b665ece59db052e476f22faa76f3aa.jpg
# Added 4 drones to GH010990_MP4_frame_1165_tile0_jpg.rf.301f244e8d03702d022f5af1db0dba6e.jpg
# Added 4 drones to GH010990_MP4_frame_824_tile2_jpg.rf.9bfea13f8b52392ed28ffa1a8abe1ab6.jpg
# Added 4 drones to GH010991_MP4_frame_61_tile2_jpg.rf.df12ad938b644e005d4bf81eacb29690.jpg
# Added 4 drones to GH010991_MP4_frame_100_tile1_jpg.rf.9159f7321feff18e724f5cce3bb03925.jpg
# Added 4 drones to GH010990_MP4_frame_1215_tile2_jpg.rf.60e3f1cecd026eac9d02f3177e10dbe6.jpg
# Added 4 drones to GH010990_MP4_frame_1126_tile1_jpg.rf.487744382e4fc8de4200a429461c095a.jpg
# Added 4 drones to GH010990_MP4_frame_1000_tile0_jpg.rf.b6d5042b789dd6623b255b6e9ac77b6b.jpg
# Added 4 drones to GH010991_MP4_frame_181_tile0_jpg.rf.c968f7ac57ff1b3c42c7e5c3d331d28c.jpg
# Added 4 drones to GH010990_MP4_frame_1170_tile1_jpg.rf.9ebe7dab3dbbb24d11bfe1f5d57835e2.jpg
# Added 4 drones to GH010990_MP4_frame_1167_tile2_jpg.rf.495da70aaa7174c36c13845c7da5207c.jpg
# Added 4 drones to GH010990_MP4_frame_1221_tile2_jpg.rf.80713d88951efcb38bf836941954e382.jpg
# Added 4 drones to GH010991_MP4_frame_49_tile0_jpg.rf.4e44f362a3307c068913faeaeb7fa353.jpg
# Added 4 drones to GH010990_MP4_frame_972_tile2_jpg.rf.60de157c2c0ac84e1561493907464c95.jpg
# Added 4 drones to GH010990_MP4_frame_1174_tile2_jpg.rf.5150ca95394dcdfa434aa9d1106d8665.jpg
# Added 4 drones to GH010991_MP4_frame_82_tile2_jpg.rf.8018e00096f96aac7c8329830a3f8664.jpg
# Added 4 drones to GH010990_MP4_frame_1226_tile1_jpg.rf.2fcc75ef38642df270760162765731fe.jpg
# Added 4 drones to GH010990_MP4_frame_1190_tile0_jpg.rf.66534f78cc9b33b68eb97a3a8cd518fa.jpg
# Added 4 drones to GH010990_MP4_frame_1012_tile1_jpg.rf.94678ca13c95122f88473cd6919e95d4.jpg
# Added 4 drones to GH010990_MP4_frame_991_tile1_jpg.rf.d43904f15a25ad9bb17a7b540e48a6c4.jpg
# Added 4 drones to GH010990_MP4_frame_1110_tile0_jpg.rf.7d4fb25c3c9f2cba9343024eb802ae3e.jpg
# Added 4 drones to GH010991_MP4_frame_65_tile0_jpg.rf.8864d6f108aa62e4ef16395a947db7be.jpg
# Added 4 drones to GH010990_MP4_frame_818_tile0_jpg.rf.38f3fb742170323873389b044b1adcc2.jpg
# Added 4 drones to GH010990_MP4_frame_1176_tile1_jpg.rf.829c7d37a9d1da8cd9255049c22044dc.jpg
# Added 4 drones to GH010991_MP4_frame_49_tile2_jpg.rf.775bff9161c3cb47913eab70278d1028.jpg
# Added 4 drones to GH010990_MP4_frame_1216_tile2_jpg.rf.b4f8e0962318ca0df69befa38f070eb7.jpg
# Added 4 drones to GH010990_MP4_frame_961_tile2_jpg.rf.f99542563bb74eaf4b2a9f14ee89cab5.jpg
# Added 4 drones to GH010991_MP4_frame_102_tile0_jpg.rf.9d1008fd0837262081f67ed017064abc.jpg
# Added 4 drones to GH010991_MP4_frame_55_tile1_jpg.rf.0e2e8f449e09da37082aec9d73dc76e9.jpg
# Added 4 drones to GH010990_MP4_frame_1012_tile0_jpg.rf.16d1b908401f8e6c4416abad10253011.jpg
# Added 4 drones to GH010990_MP4_frame_1116_tile1_jpg.rf.3dc474113b59182e9a4908fd18ee4c51.jpg
# Added 4 drones to GH010991_MP4_frame_91_tile1_jpg.rf.1aaa943974a2b11347ddceb606d08661.jpg
# Added 4 drones to GH010990_MP4_frame_1204_tile1_jpg.rf.8ddda3ad3b3af6db74876bbb3a0a4852.jpg
# Added 4 drones to GH010991_MP4_frame_25_tile0_jpg.rf.f46f43b7a1d8ce65806bb49e6cc63151.jpg
# Added 4 drones to GH010990_MP4_frame_837_tile1_jpg.rf.17710d31836b19b27581249e089be40f.jpg
# Added 4 drones to GH010990_MP4_frame_1125_tile1_jpg.rf.3c90fa1e895ba3ecbaa01f04391b3a5d.jpg
# Added 4 drones to GH010991_MP4_frame_49_tile1_jpg.rf.64e72f152b35548f2547caf1b56667e5.jpg
# Added 4 drones to GH010991_MP4_frame_28_tile1_jpg.rf.5e72f6772d9c506039aca2182462d1e7.jpg
# Added 4 drones to GH010990_MP4_frame_1008_tile0_jpg.rf.b98c1ababd5596408239d49b043df104.jpg
# Added 4 drones to GH010990_MP4_frame_960_tile2_jpg.rf.9277bb89408e55fe6f741970d2f8438c.jpg
# Added 4 drones to GH010990_MP4_frame_813_tile2_jpg.rf.44ffbd8ae6e482bb528d12ab780e8bfa.jpg
# Added 4 drones to GH010990_MP4_frame_961_tile0_jpg.rf.cd5cb56589a4b06aa9894d86a234b23f.jpg
# Added 4 drones to GH010991_MP4_frame_54_tile1_jpg.rf.adeaea59855ad7561c2cdc44323b3733.jpg
# Added 4 drones to GH010990_MP4_frame_1224_tile1_jpg.rf.20bf0ec73033ba43e387370c2af629fc.jpg
# Added 4 drones to GH010991_MP4_frame_93_tile1_jpg.rf.ee051bf2cae57f8f519109c3d14871db.jpg
# Added 4 drones to GH010991_MP4_frame_3_tile2_jpg.rf.2519d25e1723abe94e77f1a620daff8a.jpg
# Added 4 drones to GH010990_MP4_frame_1198_tile1_jpg.rf.f639dba9c7f498fa1c1ea04a8bc080b6.jpg
# Added 4 drones to GH010990_MP4_frame_1225_tile1_jpg.rf.fd5eb2c5f401e3d7bb79621ba7146c03.jpg
# Added 4 drones to GH010991_MP4_frame_94_tile2_jpg.rf.9634210b4c95a84b98988daaa4a6af90.jpg
# Added 4 drones to GH010991_MP4_frame_1_tile1_jpg.rf.990b619f038112d011cb6bf5245969d6.jpg
# Added 4 drones to GH010991_MP4_frame_95_tile1_jpg.rf.3fb718668396090394c9620be5068725.jpg
# Added 4 drones to GH010990_MP4_frame_951_tile2_jpg.rf.b02e5a28899306c5eefcd1ad9bdbb776.jpg
# Added 4 drones to GH010990_MP4_frame_1183_tile2_jpg.rf.ce9943245d1eab65fdf0eb4cca0342f1.jpg
# Added 4 drones to GH010990_MP4_frame_1184_tile2_jpg.rf.d5f3e06b243fd0c91305d07c4cf0e501.jpg
# Added 4 drones to GH010991_MP4_frame_89_tile0_jpg.rf.6e2618dedc368f7b6e7f94f5f3849f36.jpg
# Added 4 drones to GH010991_MP4_frame_72_tile1_jpg.rf.f35ffe873032c2651cf2e2873fd2eca8.jpg
# Added 4 drones to GH010991_MP4_frame_43_tile1_jpg.rf.c56fabb3a17766e8df91557b8900dab3.jpg
# Added 4 drones to GH010990_MP4_frame_1006_tile2_jpg.rf.80d309332de14de47c1a357d5d86aae0.jpg
# Added 4 drones to GH010990_MP4_frame_1196_tile1_jpg.rf.474345d43d743b6486cd722ef3b99203.jpg
# Added 4 drones to GH010991_MP4_frame_23_tile2_jpg.rf.8b4ebfa713b67c28abde7c9421073c75.jpg
# Added 4 drones to GH010990_MP4_frame_977_tile2_jpg.rf.df748a472a97fdd7a2c195d944b2c509.jpg
# Added 4 drones to GH010990_MP4_frame_1175_tile1_jpg.rf.053f12648a4d6862cafdd44526b92977.jpg
# Added 4 drones to GH010990_MP4_frame_1217_tile2_jpg.rf.5bd156afa2cfb7a6ba8e43370ef2e5dc.jpg
# Added 4 drones to GH010990_MP4_frame_1228_tile1_jpg.rf.8bc9cc24b0a04ad105bba6e822691b75.jpg
# Added 4 drones to GH010991_MP4_frame_55_tile0_jpg.rf.1fe562b78f593b31cc783fbcdc2bc780.jpg
# Added 4 drones to GH010991_MP4_frame_74_tile0_jpg.rf.6e0b0ecbbe880845244b1170bcc3f258.jpg
# Added 4 drones to GH010990_MP4_frame_1145_tile2_jpg.rf.326162ab8a1bd06b082d5828a6ff5c18.jpg
# Added 4 drones to GH010990_MP4_frame_825_tile2_jpg.rf.44e1909cd5d20af8be68698e7c921ab6.jpg
# Added 4 drones to GH010991_MP4_frame_24_tile2_jpg.rf.2039c97bd1584182e7749c83cdef1174.jpg
# Added 4 drones to GH010990_MP4_frame_1165_tile2_jpg.rf.c105c71e9b76625156cdffe4e5713d1f.jpg
# Added 4 drones to GH010990_MP4_frame_1118_tile1_jpg.rf.8a08b019e72f31d921e5dff9b4af6e5b.jpg
# Added 4 drones to GH010990_MP4_frame_1213_tile1_jpg.rf.5c4afb386c2a0a32e15bcb3c9d579469.jpg
# Added 4 drones to GH010990_MP4_frame_989_tile0_jpg.rf.92d55af8b1b1d69e648659450cb756e9.jpg
# Added 4 drones to GH010991_MP4_frame_113_tile2_jpg.rf.efb44fe180f49cf96de2996943f79939.jpg
# Added 4 drones to GH010990_MP4_frame_1212_tile1_jpg.rf.306a1dedab59308b60f6d5ec4b35450d.jpg
# Added 4 drones to GH010990_MP4_frame_1176_tile2_jpg.rf.3f325316cd662fd2198086532c0ae6dd.jpg
# Added 4 drones to GH010991_MP4_frame_97_tile2_jpg.rf.04fcac0d509e18bf51138b6b6aca27c1.jpg
# Added 4 drones to GH010990_MP4_frame_941_tile1_jpg.rf.aa3ad4447119ad4500a814fb5c4dbd8a.jpg
# Added 4 drones to GH010990_MP4_frame_942_tile1_jpg.rf.fdcfa0efed73be362439582e625242bd.jpg
# Added 4 drones to GH010990_MP4_frame_1111_tile1_jpg.rf.ad4441a2cadeeac378fb83918cc2a8a9.jpg
# Added 4 drones to GH010990_MP4_frame_966_tile2_jpg.rf.52371dabb893b3e4c098de869bb1e4ad.jpg
# Added 4 drones to GH010991_MP4_frame_90_tile2_jpg.rf.4d01ec179971757f940ac53408e88d92.jpg
# Added 4 drones to GH010990_MP4_frame_996_tile0_jpg.rf.9d8d292558979d6471790ca089de1da9.jpg
# Added 4 drones to GH010991_MP4_frame_77_tile2_jpg.rf.7636a2ca337e08525eb38b2aecf96eac.jpg
# Added 4 drones to GH010990_MP4_frame_810_tile2_jpg.rf.54f6f36824931787ec6301e06288127e.jpg
# Added 4 drones to GH010990_MP4_frame_1127_tile2_jpg.rf.ac75b0f1cd4049750a2df7951fb3a9c2.jpg
# Added 4 drones to GH010991_MP4_frame_35_tile2_jpg.rf.08b3efe71faf3a0002961ebb2ef4e67b.jpg
# Added 4 drones to GH010991_MP4_frame_22_tile1_jpg.rf.5d40f9e05989584741631fd045a60d57.jpg
# Added 4 drones to GH010991_MP4_frame_106_tile2_jpg.rf.1c003c227a4c30734dac5e66d4e7ba1a.jpg
# Added 4 drones to GH010990_MP4_frame_801_tile1_jpg.rf.6b09fd2b418585732426a034a0aa9579.jpg
# Added 4 drones to GH010990_MP4_frame_1155_tile1_jpg.rf.7b612fbacccea3d317dde26ed6b321c4.jpg
# Added 4 drones to GH010990_MP4_frame_1148_tile1_jpg.rf.04dc081f2e3148c89dc1af5301c62659.jpg
# Added 4 drones to GH010990_MP4_frame_1164_tile1_jpg.rf.bed9f3f8caaad6ccc874a9ca161a610c.jpg
# Added 4 drones to GH010991_MP4_frame_20_tile2_jpg.rf.677eaa9d147f50e63b1094e31e155c52.jpg
# Added 4 drones to GH010990_MP4_frame_951_tile1_jpg.rf.73f058dcaa7e465f2894fc610da88355.jpg
# Added 4 drones to GH010990_MP4_frame_778_tile1_jpg.rf.cf486b76bb670f076a42155b797ac2f1.jpg
# Added 4 drones to GH010990_MP4_frame_1112_tile2_jpg.rf.accc7db16f789844b1b7d56aeb25016d.jpg
# Added 4 drones to GH010990_MP4_frame_831_tile0_jpg.rf.2919d90685ef99d18750f99083c429c0.jpg
# Added 4 drones to GH010990_MP4_frame_1168_tile0_jpg.rf.1aab067ae6b9820fc3f8afd5242f7ba5.jpg
# Added 4 drones to GH010991_MP4_frame_104_tile0_jpg.rf.6090db622a6c69b1307488416d75ed50.jpg
# Added 4 drones to GH010990_MP4_frame_1013_tile1_jpg.rf.dfe04619f4b154219890d41fe3a7041a.jpg
# Added 4 drones to GH010990_MP4_frame_826_tile1_jpg.rf.42b720e6485cdc6f51bb2107153adca6.jpg
# Added 4 drones to GH010990_MP4_frame_849_tile0_jpg.rf.4577121fe8edb39d36ff5dbbc7efc5ec.jpg
# Added 4 drones to GH010991_MP4_frame_38_tile2_jpg.rf.008e4f0750ccb902ffd5ad4b83cb4510.jpg
# Added 4 drones to GH010990_MP4_frame_849_tile2_jpg.rf.12ec118a4ed97babee980f349b0427a7.jpg
# Added 4 drones to GH010990_MP4_frame_1008_tile1_jpg.rf.f215922de5cfedd2256eaca1d16c145c.jpg
# Added 4 drones to GH010990_MP4_frame_965_tile0_jpg.rf.d4e208b987e03cbf1a18aca5be8c5e69.jpg
# Added 4 drones to GH010990_MP4_frame_1118_tile0_jpg.rf.24c4587d5fb315e04756adba4a4f6c9b.jpg
# Added 4 drones to GH010991_MP4_frame_109_tile2_jpg.rf.92137fbb034885ad526fd30463883032.jpg
# Added 4 drones to GH010990_MP4_frame_1109_tile1_jpg.rf.7b24cb7b3e51824c2b1e7ca71f54d4d2.jpg
# Added 4 drones to GH010990_MP4_frame_1162_tile2_jpg.rf.088c56af24accb0c1888137a03b69ba4.jpg
# Added 4 drones to GH010990_MP4_frame_948_tile0_jpg.rf.d0bce09a68c69d7b4aad740b40e8242b.jpg
# Added 4 drones to GH010991_MP4_frame_115_tile0_jpg.rf.9b0a7e54533a8820b29eafe860734bc6.jpg
# Added 4 drones to GH010990_MP4_frame_938_tile1_jpg.rf.8ef60fd71801ac7991b39c447edf17dc.jpg
# Added 4 drones to GH010990_MP4_frame_992_tile0_jpg.rf.981b66cf6648c497ff76680ebd2b6b7b.jpg
# Added 4 drones to GH010990_MP4_frame_1179_tile0_jpg.rf.8e06bfb14a5910f47af8da0cd5c0102e.jpg
# Added 4 drones to GH010991_MP4_frame_114_tile0_jpg.rf.e953a4528935196643378f1aac1fe35d.jpg
# Added 4 drones to GH010991_MP4_frame_98_tile1_jpg.rf.26965886cef9898eb74b419d88534681.jpg
# Added 4 drones to GH010990_MP4_frame_1003_tile2_jpg.rf.e9aded8e891e77c55c39e7dda6148bac.jpg
# Added 4 drones to GH010990_MP4_frame_1119_tile0_jpg.rf.0ca3b88b567563198d7364d628a79c70.jpg
# Added 4 drones to GH010990_MP4_frame_1172_tile0_jpg.rf.8224377626e411982514e504a28714da.jpg
# Added 4 drones to GH010990_MP4_frame_1211_tile2_jpg.rf.e5f059d16cb0704d30cc594353ac484a.jpg
# Added 4 drones to GH010990_MP4_frame_1115_tile2_jpg.rf.85f8577844353e8095d2e942859b2c0a.jpg
# Added 4 drones to GH010990_MP4_frame_817_tile2_jpg.rf.49ee5e56a8f7fd9e9b93e4536b1d9c57.jpg
# Added 4 drones to GH010991_MP4_frame_42_tile2_jpg.rf.37e02f3148dfae2b9f28d3be50a2257e.jpg
# Added 3 drones to GH010991_MP4_frame_34_tile1_jpg.rf.965dc3c1fdb5f7e81af1629bd8af24a8.jpg
#
# Total added: 2691 drones across 820 images

# %%
worker_count = 0
drone_count = 0

for split in ["train"]:
    for lbl_file in (base/split/"labels").glob("*.txt"):
        labels = [line.split()[0] for line in open(lbl_file)]
        worker_count += labels.count("0")
        drone_count  += labels.count("1")

print("Workers:", worker_count)
print("Drones:", drone_count)
# Out:
# Workers: 6318
# Drones: 3159

# %%
plt.figure(figsize=(6,4))
plt.bar(["Worker", "Drone"], [worker_count, drone_count], color=["#FFD700", "#1E90FF"])
plt.title("Worker vs Drone Count (Train Set)")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# **Double check whether we meet the ratio**, if not then just run again the code

# %%
target_drones = worker_count // 2
needed = target_drones - drone_count
print("Still need:", needed, "more drones")
# Out:
# Still need: 0 more drones

# %% [markdown]
# **Training on balanced data**

# %%
base_path = Path("/content/Worker/Drone-2")
data_yaml_path = base_path / "data.yaml"
if not data_yaml_path.exists():
    print(f"ERROR: data.yaml not found at {data_yaml_path}. Check Roboflow download settings.")
else:
    print(f"Using data configuration from: {data_yaml_path}")

    # pre-trained YOLOv10n model weights
    model = YOLO("yolov10n.pt")

    results = model.train(
        data=str(data_yaml_path),
        epochs=50,
        imgsz=1280,
        name="yolov10_worker_drone_balanced_run"
    )

    print("Training Complete!")
# Out:
# Using data configuration from: /content/Worker/Drone-2/data.yaml
# Ultralytics 8.3.234 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/Worker/Drone-2/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=1280, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov10n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=yolov10_worker_drone_balanced_run, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/detect/yolov10_worker_drone_balanced_run, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1      9856  ultralytics.nn.modules.block.SCDown          [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1     36096  ultralytics.nn.modules.block.SCDown          [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.PSA             [256, 256]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  20                  -1  1     18048  ultralytics.nn.modules.block.SCDown          [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    282624  ultralytics.nn.modules.block.C2fCIB          [384, 256, 1, True, True]
#  23        [16, 19, 22]  1    862108  ultralytics.nn.modules.head.v10Detect        [2, [64, 128, 256]]
# YOLOv10n summary: 223 layers, 2,707,820 parameters, 2,707,804 gradients, 8.4 GFLOPs
#
# Transferred 493/595 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2565.0±875.0 MB/s, size: 215.0 KB)
# train: Scanning /content/Worker/Drone-2/train/labels... 820 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 820/820 2.4Kit/s 0.3s
# train: New cache created: /content/Worker/Drone-2/train/labels.cache
# albumentations: ImageCompression.__init__() got an unexpected keyword argument 'quality_range'
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 614.3±383.5 MB/s, size: 119.8 KB)
# val: Scanning /content/Worker/Drone-2/valid/labels.cache... 100 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 100/100 29.4Kit/s 0.0s
# Plotting labels to /content/runs/detect/yolov10_worker_drone_balanced_run/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 95 weight(decay=0.0), 108 weight(decay=0.0005), 107 bias(decay=0.0)
# Image sizes 1280 train, 1280 val
# Using 2 dataloader workers
# Logging results to /content/runs/detect/yolov10_worker_drone_balanced_run
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      13.6G      2.184      5.881      2.342         52       1280: 100% ━━━━━━━━━━━━ 52/52 1.5s/it 1:18
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.1s/it 8.3s
#                    all        100        810     0.0369      0.906       0.28      0.149
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      11.6G      2.097      3.805      2.181        102       1280: 100% ━━━━━━━━━━━━ 52/52 1.1it/s 47.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.5s
#                    all        100        810      0.702      0.389      0.518      0.294
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      11.4G      2.181      3.208      2.188         75       1280: 100% ━━━━━━━━━━━━ 52/52 1.0it/s 49.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.6s
#                    all        100        810      0.555      0.655      0.601      0.328
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      11.3G      2.129      2.711      2.172         88       1280: 100% ━━━━━━━━━━━━ 52/52 1.0it/s 50.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.5s
#                    all        100        810      0.632      0.633       0.66      0.353
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      11.4G       2.07      2.301      2.171         44       1280: 100% ━━━━━━━━━━━━ 52/52 1.0it/s 49.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.4it/s 2.8s
#                    all        100        810      0.845      0.732      0.803       0.47
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      11.5G      1.994      1.945      2.123         70       1280: 100% ━━━━━━━━━━━━ 52/52 1.1it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.5s
#                    all        100        810       0.81      0.794      0.836      0.488
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      11.4G       2.02      1.814      2.148         49       1280: 100% ━━━━━━━━━━━━ 52/52 1.0it/s 49.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.5s
#                    all        100        810      0.755      0.711      0.783      0.461
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      11.4G      1.989      1.668      2.127         62       1280: 100% ━━━━━━━━━━━━ 52/52 1.1it/s 48.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.6s
#                    all        100        810       0.75      0.774      0.776      0.465
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      11.3G       1.98      1.536      2.121        101       1280: 100% ━━━━━━━━━━━━ 52/52 1.1it/s 49.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.5s
#                    all        100        810      0.845       0.71      0.832      0.504
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      11.4G      1.895      1.401      2.086         43       1280: 100% ━━━━━━━━━━━━ 52/52 1.1it/s 49.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.3it/s 3.1s
#                    all        100        810      0.847      0.701      0.799      0.467
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      11.3G      1.916      1.366      2.095         33       1280: 100% ━━━━━━━━━━━━ 52/52 1.1it/s 48.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.5s
#                    all        100        810      0.829      0.728      0.812      0.494
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      11.2G      1.903      1.298      2.083         53       1280: 100% ━━━━━━━━━━━━ 52/52 1.1it/s 48.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.4s
#                    all        100        810      0.839      0.801      0.877      0.506
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      11.5G      1.864      1.229      2.062         58       1280: 100% ━━━━━━━━━━━━ 52/52 1.0it/s 49.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.8it/s 2.3s
#                    all        100        810      0.892      0.852      0.893      0.518
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      11.4G      1.895      1.231      2.097         51       1280: 100% ━━━━━━━━━━━━ 52/52 1.0it/s 50.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.6s
#                    all        100        810      0.873      0.821      0.877      0.542
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      11.4G      1.831      1.153      2.054         64       1280: 100% ━━━━━━━━━━━━ 52/52 1.1it/s
0.644
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      11.1G      1.363     0.6125      1.883         40       1280: 100% ━━━━━━━━━━━━ 52/52 1.1it/s 46.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.4s
#                    all        100        810       0.94      0.888      0.946      0.635
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      11.1G      1.332     0.5975      1.866         35       1280: 100% ━━━━━━━━━━━━ 52/52 1.1it/s 46.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.5s
#                    all        100        810      0.937      0.888      0.946      0.644
#
# 50 epochs completed in 0.754 hours.
# Optimizer stripped from /content/runs/detect/yolov10_worker_drone_balanced_run/weights/last.pt, 5.9MB
# Optimizer stripped from /content/runs/detect/yolov10_worker_drone_balanced_run/weights/best.pt, 5.9MB
#
# Validating /content/runs/detect/yolov10_worker_drone_balanced_run/weights/best.pt...
# Ultralytics 8.3.234 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv10n summary (fused): 102 layers, 2,265,558 parameters, 0 gradients, 6.5 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.0it/s 4.0s
#                    all        100        810      0.923        0.9      0.946      0.643
#                      0        100        741      0.918      0.872      0.923      0.646
#                      1         54         69      0.929      0.928      0.969       0.64
# Speed: 0.8ms preprocess, 9.8ms inference, 0.0ms loss, 0.8ms postprocess per image
# Results saved to /content/runs/detect/yolov10_worker_drone_balanced_run
# Training Complete!

# %%
best_model_path = Path("/content/runs/detect/yolov10_worker_drone_balanced_run/weights/best.pt")
best_model = YOLO(str(best_model_path))

metrics_bal = best_model.val()
print("\n--- Model Performance Metrics ---")
print(f"mAP50-95: {metrics.box.map:.4f}")
print(f"mAP50: {metrics.box.map50:.4f}")
# Out:
# Ultralytics 8.3.234 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv10n summary (fused): 102 layers, 2,265,558 parameters, 0 gradients, 6.5 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1607.0±517.3 MB/s, size: 80.0 KB)
# val: Scanning /content/Worker/Drone-2/valid/labels.cache... 100 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 100/100 115.5Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.1it/s 6.2s
#                    all        100        810      0.947      0.881      0.946      0.644
#                      0        100        741      0.948      0.835      0.924      0.646
#                      1         54         69      0.946      0.928      0.969      0.642
# Speed: 20.8ms preprocess, 13.7ms inference, 0.0ms loss, 0.3ms postprocess per image
# Results saved to /content/runs/detect/val5
#
# --- Model Performance Metrics ---
# mAP50-95: 0.6236
# mAP50: 0.9391

# %%
ap_per_class = metrics_bal.box.ap

ap50_per_class = metrics_bal.box.ap50

names = metrics_bal.names
class_names = [names[i] for i in sorted(names.keys())]
print("--- Class-Specific Average Precision (AP) ---")

for i, name in enumerate(class_names):

    ap95_score = ap_per_class[i]
    ap50_score = ap50_per_class[i]

    print(f"\n{name} (Class {i}):")
    print(f"  AP@0.5 (AP50):      {ap50_score:.4f}")
    print(f"  AP@0.5:0.95 (AP95): {ap95_score:.4f}")
# Out:
# --- Class-Specific Average Precision (AP) ---
#
# 0 (Class 0):
#   AP@0.5 (AP50):      0.9236
#   AP@0.5:0.95 (AP95): 0.6463
#
# 1 (Class 1):
#   AP@0.5 (AP50):      0.9692
#   AP@0.5:0.95 (AP95): 0.6421

# %%
matrix_path = "/content/runs/detect/yolov10_worker_drone_balanced_run/confusion_matrix.png"
normalized_path = "/content/runs/detect/yolov10_worker_drone_balanced_run/confusion_matrix_normalized.png"

print("Confusion matrix:")

img = mpimg.imread(matrix_path)
plt.imshow(img)
plt.axis('off')
plt.show()

print("\nConfusion matrix normalized:")
img_normalized = mpimg.imread(normalized_path)
plt.imshow(img_normalized)
plt.axis('off')
plt.show()
# Out:
# Confusion matrix:
# Confusion matrix normalized:
